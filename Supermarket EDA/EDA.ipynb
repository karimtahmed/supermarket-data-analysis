# %%
import seaborn as sns
import pandas as pd
import numpy as np
sns.set(rc={'figure.figsize':[6,6]}, font_scale=1.4)

# %%
df=pd.read_csv('Data.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#total sales of all three branches
#difference in sales between three branches?
#who purchases more products in A males or females ?
#people pay more in which payment types in A?
#which customer type purchases more in A?
#who pays more normal or member in C?
#who pays more normal or member in total branches?
#best times we sale
#best date we sale
#average rating for every branch
#average rating for supermarket
#average profit for every branch
#average profit for total branches
#most product bought in every branch
#most product bought by each gender

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df.groupby('Branch').describe()
# Out:
#        Unit price                                                         \
#             count       mean        std    min      25%     50%      75%
# Branch
# A           340.0  54.780853  26.132127  10.08  32.2500  53.235  75.0950
# B           332.0  55.659277  26.224559  10.59  33.3000  54.850  77.0025
# C           328.0  56.609024  27.179799  10.16  33.7675  56.810  81.5525
#
#               Quantity            ... gross income        Rating            \
#           max    count      mean  ...          75%    max  count      mean
# Branch                            ...
# A       99.83    340.0  5.467647  ...    21.873375  49.49  340.0  7.027059
# B       99.96    332.0  5.481928  ...    22.170750  48.69  332.0  6.818072
# C       99.96    328.0  5.582317  ...    23.607375  49.65  328.0  7.072866
#
#
#              std  min  25%  50%  75%   max
# Branch
# A       1.731345  4.0  5.6  7.1  8.5  10.0
# B       1.713719  4.0  5.3  6.7  8.2  10.0
# ...

# %% [markdown]
# most branch cogs is c

# %%
df.groupby('Branch')['cogs'].sum()
# Out:
# Branch
# A    101143.21
# B    101140.64
# C    105303.53
# Name: cogs, dtype: float64

# %% [markdown]
# most profitable branch is C

# %%
sns.barplot(x='Branch',y='cogs',data=df,estimator=np.sum)
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='cogs'>

# %%
df.groupby('Branch')['Quantity'].count()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: Quantity, dtype: int64

# %% [markdown]
# most purchased orders is in A

# %%
df.groupby('Branch')['Rating'].mean()
# Out:
# Branch
# A    7.027059
# B    6.818072
# C    7.072866
# Name: Rating, dtype: float64

# %% [markdown]
# most rated branch is C

# %%
df['Rating'].mean()
# Out:
# 6.9727

# %%
x=pd.pivot_table(index='Product line',values='Quantity',columns='Gender',data=df,aggfunc=np.sum)

# %%
x
# Out:
# Gender                  Female  Male
# Product line
# Electronic accessories     488   483
# Fashion accessories        530   372
# Food and beverages         514   438
# Health and beauty          343   511
# Home and lifestyle         498   413
# Sports and travel          496   424

# %%
sns.heatmap(x)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Product line'>

# %% [markdown]
# males most purchased product type is health and beauty. while women most purchased product type isFashion accessories.

# %%
df.groupby('Gender')['Total'].sum()
# Out:
# Gender
# Female    167882.925
# Male      155083.824
# Name: Total, dtype: float64

# %%
sns.barplot(x='T',y='Total',data=df,estimator=np.sum)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Total'>

# %% [markdown]
# women pay and purchases more orders than men.

# %%
z=df['Payment'].value_counts()

# %%
z
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
sns.histplot( x='Payment' , data=df)
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Count'>

# %%
df.groupby('Payment')['Total'].sum()
# Out:
# Payment
# Cash           112206.570
# Credit card    100767.072
# Ewallet        109993.107
# Name: Total, dtype: float64

# %% [markdown]
# ewallet and cash is more than credit card payments. make discount for paying with credit card.

# %%
x=pd.pivot_table(index='Branch',values='Total',columns='Gender',data=df,aggfunc=np.sum)
x
# Out:
# Gender     Female        Male
# Branch
# A       53269.167  52931.2035
# B       52928.295  53269.3770
# C       61685.463  48883.2435

# %%
sns.heatmap(x)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Branch'>

# %%
x=pd.pivot_table(index='Gender',values='Quantity',columns='Branch',data=df,aggfunc=np.sum)
x
# Out:
# Branch    A    B     C
# Gender
# Female  909  911  1049
# Male    950  909   782

# %% [markdown]
# men purchase more in A but total is less than women.
# women purchase more in B but total is less than men.
# men purchase less in C and total is less than women.
# women most pay in branch C

# %%
z=df['Time'].value_counts()
z
# Out:
# 14:42    7
# 19:48    7
# 17:38    6
# 11:51    5
# 19:30    5
#         ..
# 20:15    1
# 16:17    1
# 14:57    1
# 11:29    1
# 13:35    1
# Name: Time, Length: 506, dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'], format='%m-%d-%Y', infer_datetime_format=True)
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
z=df['Date'].value_counts()
z
# Out:
# 2019-02-07    20
# 2019-02-15    19
# 2019-03-02    18
# 2019-03-14    18
# 2019-01-08    18
#               ..
# 2019-01-04     6
# 2019-02-01     6
# 2019-02-28     6
# 2019-03-17     6
# 2019-02-21     6
# Name: Date, Length: 89, dtype: int64

# %%
df['Month']=df['Date'].dt.month
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
z=df['Month'].value_counts()
z
# Out:
# 1    352
# 3    345
# 2    303
# Name: Month, dtype: int64

# %% [markdown]
# the supermarket only sale on months 1,2 and 3

# %%
x=pd.pivot_table(index='Month',values='Quantity',columns='Gender',data=df,aggfunc=np.sum)
x
# Out:
# Gender  Female  Male
# Month
# 1         1019   946
# 2          951   703
# 3          899   992

# %%
sns.heatmap(x)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Month'>
